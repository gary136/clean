# %%
import os

# %%
os.chdir('C:\projectData\leaseCleaned\cle_csv')

# %%
import pandas as pd
data = []
for root, dirs, files in os.walk(".", topdown=False):
    for name in files:
#         print(os.path.join(root, name))
#         fullname = os.path.join(root, name)
#         data.append(fullname)
        data.append(name)

# %%
data.pop(0)
# Out:
# 'hardware.csv'

# %%
data
# Out:
# ['lease_100_2008.csv',
#  'lease_100_2009.csv',
#  'lease_100_2010.csv',
#  'lease_100_2011.csv',
#  'lease_100_2012.csv',
#  'lease_100_2013.csv',
#  'lease_100_2014.csv',
#  'lease_100_2015.csv',
#  'lease_100_2016.csv',
#  'lease_100_2017.csv',
#  'lease_100_2018.csv',
#  'lease_103_2008.csv',
#  'lease_103_2009.csv',
#  'lease_103_2010.csv',
#  'lease_103_2011.csv',
#  'lease_103_2012.csv',
#  'lease_103_2013.csv',
#  'lease_103_2014.csv',
#  'lease_103_2015.csv',
#  'lease_103_2016.csv',
#  'lease_103_2017.csv',
#  'lease_103_2018.csv',
#  'lease_104_2008.csv',
#  'lease_104_2009.csv',
#  'lease_104_2010.csv',
#  'lease_104_2011.csv',
#  'lease_104_2012.csv',
#  'lease_104_2013.csv',
#  'lease_104_2014.csv',
#  'lease_104_2015.csv',
#  'lease_104_2016.csv',
#  'lease_104_2017.csv',
#  'lease_104_2018.csv',
#  'lease_105_2008.csv',
#  'lease_105_2009.csv',
#  'lease_105_2010.csv',
#  'lease_105_2011.csv',
#  'lease_105_2012.csv',
#  'lease_105_2013.csv',
#  'lease_105_2014.csv',
#  'lease_105_2015.csv',
#  'lease_105_2016.csv',
#  'lease_105_2017.csv',
#  'lease_105_2018.csv',
#  'lease_106_2008.csv',
#  'lease_106_2009.csv',
#  'lease_106_2010.csv',
#  'lease_106_2011.csv',
#  'lease_106_2012.csv',
#  'lease_106_2013.csv',
#  'lease_106_2014.csv',
#  'lease_106_2015.csv',
#  'lease_106_2016.csv',
#  'lease_106_2017.csv',
#  'lease_106_2018.csv',
#  'lease_108_2008.csv',
#  'lease_108_2009.csv',
#  'lease_108_2010.csv',
#  'lease_108_2011.csv',
#  'lease_108_2012.csv',
#  'lease_108_2013.csv',
#  'lease_108_2014.csv',
#  'lease_108_2015.csv',
#  'lease_108_2016.csv',
#  'lease_108_2017.csv',
#  'lease_110_2008.csv',
#  'lease_110_2009.csv',
#  'lease_110_2010.csv',
#  'lease_110_2011.csv',
#  'lease_110_2012.csv',
#  'lease_110_2013.csv',
#  'lease_110_2014.csv',
#  'lease_110_2015.csv',
#  'lease_110_2016.csv',
#  'lease_110_2017.csv',
#  'lease_110_2018.csv',
#  'lease_111_2008.csv',
#  'lease_111_2009.csv',
#  'lease_111_2010.csv',
#  'lease_111_2011.csv',
#  'lease_111_2012.csv',
#  'lease_111_2013.csv',
#  'lease_111_2014.csv',
#  'lease_111_2015.csv',
#  'lease_111_2016.csv',
#  'lease_111_2017.csv',
#  'lease_111_2018.csv',
#  'lease_112_2008.csv',
#  'lease_112_2009.csv',
#  'lease_112_2010.csv',
#  'lease_112_2011.csv',
#  'lease_112_2012.csv',
#  'lease_112_2013.csv',
#  'lease_112_2014.csv',
#  'lease_112_2015.csv',
#  'lease_112_2016.csv',
#  'lease_112_2017.csv',
#  'lease_112_2018.csv',
#  'lease_114_2008.csv',
#  'lease_114_2009.csv',
#  'lease_114_2010.csv',
#  'lease_114_2011.csv',
#  'lease_114_2012.csv',
#  'lease_114_2013.csv',
#  'lease_114_2014.csv',
#  'lease_114_2015.csv',
#  'lease_114_2016.csv',
#  'lease_114_2017.csv',
#  'lease_114_2018.csv',
#  'lease_115_2008.csv',
#  'lease_115_2009.csv',
#  'lease_115_2010.csv',
#  'lease_115_2011.csv',
#  'lease_115_2012.csv',
#  'lease_115_2013.csv',
#  'lease_115_2014.csv',
#  'lease_115_2015.csv',
#  'lease_115_2016.csv',
#  'lease_115_2017.csv',
#  'lease_115_2018.csv',
#  'lease_116_2008.csv',
#  'lease_116_2009.csv',
#  'lease_116_2010.csv',
#  'lease_116_2011.csv',
#  'lease_116_2012.csv',
#  'lease_116_2013.csv',
#  'lease_116_2014.csv',
#  'lease_116_2015.csv',
#  'lease_116_2016.csv',
#  'lease_116_2017.csv',
#  'lease_116_2018.csv']

# %%
import shutil

# %%
y = range(2008,2019)
for i in y:
    if not os.path.exists(str(i)):
        os.makedirs(str(i))

# %%
for i in y:
    for j in data:
        if str(i) in j:
            path = './' + str(i) + '/' + j
            shutil.move(j, path)

# %%
dir_data = []
for root, dirs, files in os.walk(".", topdown=False):
    for name in dirs:
#         print(os.path.join(root, name))
#         fullname = os.path.join(root, name)
#         data.append(fullname)
        dir_data.append(name)

# %%
dir_data
# Out:
# ['2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018']

# %%
roo = 'C:\projectData\leaseCleaned\cle_csv'
for y in dir_data:
    print(y)
    path = roo + '/' + y
    os.chdir(path)
    data = []
    for root, dirs, files in os.walk(".", topdown=False):
        for name in files:
    #         print(os.path.join(root, name))
    #         fullname = os.path.join(root, name)
    #         data.append(fullname)
            data.append(name)
    f = []
    for i in data:
        df = pd.read_csv(i)
        f.append(df)
    df_sum = pd.concat(f) 
    name = roo + '/lease_all_' + y + '.csv'      
    df_sum.to_csv(name, index=False)
# Out:
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018

# %%
data
# Out:
# ['lease_100_2008.csv',
#  'lease_103_2008.csv',
#  'lease_104_2008.csv',
#  'lease_105_2008.csv',
#  'lease_106_2008.csv',
#  'lease_108_2008.csv',
#  'lease_110_2008.csv',
#  'lease_111_2008.csv',
#  'lease_112_2008.csv',
#  'lease_114_2008.csv',
#  'lease_115_2008.csv',
#  'lease_116_2008.csv']

# %%
f = []
for i in data:
    df = pd.read_csv(i)
    f.append(df)
df_sum = pd.concat(f)

# %%
df_sum.to_csv('test.csv', index=False)

# %%
dis = {
    '中正區': 100,
    '大同區': 103,
    '中山區': 104,
    '松山區': 105,
    '大安區': 106,
    '萬華區': 108,
    '信義區': 110,
    '士林區': 111,
    '北投區': 112,
    '內湖區': 114,
    '南港區': 115,
    '文山區': 116
}
name = data[0]
num = dis.get(data[0][:3])
year = data[0][3:7]
new_name = 'lease_{}_{}.csv'.format(num, year)
new_name
# Out:
# 'lease_104_2008.csv'

# %%
for name in data:
#     print(name)
    df = pd.read_excel(name)
    num = dis.get(name[:3])
    year = name[3:7]
    new_name = 'lease_{}_{}.csv'.format(num, year)
    print(new_name)
    df.to_csv(new_name, index=False)
# Out:
# lease_104_2008.csv
# lease_104_2009.csv
# lease_104_2010.csv
# lease_104_2011.csv
# lease_104_2012.csv
# lease_104_2013.csv
# lease_104_2014.csv
# lease_104_2015.csv
# lease_104_2016.csv
# lease_104_2017.csv
# lease_104_2018.csv
# lease_100_2008.csv
# lease_100_2009.csv
# lease_100_2010.csv
# lease_100_2011.csv
# lease_100_2012.csv
# lease_100_2013.csv
# lease_100_2014.csv
# lease_100_2015.csv
# lease_100_2016.csv
# lease_100_2017.csv
# lease_100_2018.csv
# lease_110_2008.csv
# lease_110_2009.csv
# lease_110_2010.csv
# lease_110_2011.csv
# lease_110_2012.csv
# lease_110_2013.csv
# lease_110_2014.csv
# lease_110_2015.csv
# lease_110_2016.csv
# lease_110_2017.csv
# lease_110_2018.csv
# lease_114_2008.csv
# lease_114_2009.csv
# lease_114_2010.csv
# lease_114_2011.csv
# lease_114_2012.csv
# lease_114_2013.csv
# lease_114_2014.csv
# lease_114_2015.csv
# lease_114_2016.csv
# lease_114_2017.csv
# lease_114_2018.csv
# lease_112_2008.csv
# lease_112_2009.csv
# lease_112_2010.csv
# lease_112_2011.csv
# lease_112_2012.csv
# lease_112_2013.csv
# lease_112_2014.csv
# lease_112_2015.csv
# lease_112_2016.csv
# lease_112_2017.csv
# lease_112_2018.csv
# lease_115_2008.csv
# lease_115_2009.csv
# lease_115_2010.csv
# lease_115_2011.csv
# lease_115_2012.csv
# lease_115_2013.csv
# lease_115_2014.csv
# lease_115_2015.csv
# lease_115_2016.csv
# lease_115_2017.csv
# lease_115_2018.csv
# lease_111_2008.csv
# lease_111_2009.csv
# lease_111_2010.csv
# lease_111_2011.csv
# lease_111_2012.csv
# lease_111_2013.csv
# lease_111_2014.csv
# lease_111_2015.csv
# lease_111_2016.csv
# lease_111_2017.csv
# lease_111_2018.csv
# lease_103_2008.csv
# lease_103_2009.csv
# lease_103_2010.csv
# lease_103_2011.csv
# lease_103_2012.csv
# lease_103_2013.csv
# lease_103_2014.csv
# lease_103_2015.csv
# lease_103_2016.csv
# lease_103_2017.csv
# lease_103_2018.csv
# lease_106_2008.csv
# lease_106_2009.csv
# lease_106_2010.csv
# lease_106_2011.csv
# lease_106_2012.csv
# lease_106_2013.csv
# lease_106_2014.csv
# lease_106_2015.csv
# lease_106_2016.csv
# lease_106_2017.csv
# lease_106_2018.csv
# lease_116_2008.csv
# lease_116_2009.csv
# lease_116_2010.csv
# lease_116_2011.csv
# lease_116_2012.csv
# lease_116_2013.csv
# lease_116_2014.csv
# lease_116_2015.csv
# lease_116_2016.csv
# lease_116_2017.csv
# lease_116_2018.csv
# lease_105_2008.csv
# lease_105_2009.csv
# lease_105_2010.csv
# lease_105_2011.csv
# lease_105_2012.csv
# lease_105_2013.csv
# lease_105_2014.csv
# lease_105_2015.csv
# lease_105_2016.csv
# lease_105_2017.csv
# lease_105_2018.csv
# lease_108_2008.csv
# lease_108_2009.csv
# lease_108_2010.csv
# lease_108_2011.csv
# lease_108_2012.csv
# lease_108_2013.csv
# lease_108_2014.csv
# lease_108_2015.csv
# lease_108_2016.csv
# lease_108_2017.csv

# %%
df = pd.read_csv(data[1])
# Out:
#    companyNumber conpanyName  storeNumber   storeName  \
# 0       22555003  統一超商股份有限公司      1846195  台北市第一七０分公司
# 1       22555003  統一超商股份有限公司     16080140  台北巿第三四二分公司
# 2       22555003  統一超商股份有限公司     16082148  台北巿第二二四分公司
# 3       22555003  統一超商股份有限公司     16082175  台北巿第２３３分公司
# 4       22555003  統一超商股份有限公司     16082787  台北巿第３４３分公司
#
#                      Address  Status        lat        long
# 0            臺北市士林區文林路一六九號一樓       1  25.089503  121.526791
# 1            臺北市松山區健康路224號１樓       1  25.053838  121.561100
# 2       臺北市中山區民權東路3段71、73號1樓       1  25.062576  121.543513
# 3  臺北市東新街八十巷１號１樓、１０８巷２弄三十號１樓       1  25.032969  121.565418
# 4           臺北市中山區民生東路二段１５７號       1  25.058122  121.535855

# %%
df.head()
# Out:
#   companyName  storeNumber   storeName                 address        lat  \
# 0        統一超商      1846195  台北市第一七０分公司            士林區文林路一六九號一樓  25.089503
# 1        統一超商     16080140  台北巿第三四二分公司            松山區健康路224號１樓  25.053838
# 2        統一超商     16082148  台北巿第二二四分公司       中山區民權東路3段71、73號1樓  25.062576
# 3        統一超商     16082175  台北巿第２３３分公司  東新街八十巷１號１樓、１０８巷２弄三十號１樓  25.032969
# 4        統一超商     16082787  台北巿第３４３分公司           中山區民生東路二段１５７號  25.058122
#
#           lon
# 0  121.526791
# 1  121.561100
# 2  121.543513
# 3  121.565418
# 4  121.535855

# %%
df.drop(['companyNumber','Status'], axis=1, inplace=True)

# %%
list(df.columns)
# Out:
# ['companyName', 'storeNumber', 'storeName', 'address', 'lat', 'lon']

# %%
df['conpanyName'] = df['conpanyName'].apply(lambda x:x[:-6])

# %%
df.columns = ['companyName', 'storeNumber', 'storeName', 'address', 'lat', 'lon']

# %%
df['address'] = df['address'].apply(lambda x:x[3:])

# %%
df.to_csv('convStore_done.csv', index=False)

# %%
# part 5 geocode
import pandas as pd
import numpy as np
import requests
import time
from bs4 import BeautifulSoup

new_key1 = 'AIzaSyA1yfLkwTFPMVUs6Ms8VBvHp1EarM-PL0Q'
new_key2 = 'AIzaSyDzpcg00DecOXcDrRrVw16V_yOYj8H62XM'
new_key3 = 'AIzaSyDebea1g0MYe_AM44BrW5IkEwVIQrjzof4'
new_key4 = 'AIzaSyCGQ9tGC8H2hpfwRHycKRZBic78eEfBEF0'
new_key5 = 'AIzaSyBWzTtSzpf9u9Wxki_AKKR9CrvhO_Iw0gQ'
new_key6 = 'AIzaSyDFNqrxtoAHYAQVA0QVim0nM7bAivpXm5w'
new_key7 = 'AIzaSyA2q3Zo3RDCNtYw4rzmO4rCyB41ZozJK6I'
new_key8 = 'AIzaSyDCvTAN8k57d-w_D5P8Pur2nJwHs7DNOSY'
key1 = 'AIzaSyC_vcarGfMvLtfT9Hzgn1Q8ZgUbShHDSjk'
key2 = 'AIzaSyBQlgzxJoj-bFlT1HkIY6rAYeTFrT_YcSE'
key3 = 'AIzaSyArwew-mKF3WtQ_TSOvCTJl-2PfSatDvaQ'
key4 = 'AIzaSyBnoc6s57rpUmrzXyGkeXvjteWKhXL8VKI'
key5 = 'AIzaSyDDUiVULyAhtJ_RJSyP3TUOTk_fK9ir6YI'
key6 = 'AIzaSyD5X8K0uC3aLMuJ6crbbc0djiyEIWJb9kk'
key7 = 'AIzaSyCO0xnAgE7AT1a6c29A_PZWDsQl_yXIlI8'
key8 = 'AIzaSyCoF0hPC9XSwprvJ7QTn9sRsnNceo9j-tE'

key_list = [new_key1, new_key2, new_key3, new_key4, new_key5, new_key6, new_key7, new_key8,
            key1, key2, key3, key4, key5, key6, key7, key8]

def geoc(df, key_num1):
    if 'lat' not in df.columns:
        df['lat'] = pd.Series(np.zeros(len(df)), index=df.index)
        df['long'] = pd.Series(np.zeros(len(df)), index=df.index)
#     start_n = input("starting number ")
    print("the current key number is " + str(key_num1))
#     for i in range(int(start_n), len(df)):
    i = 0
    global keyStatus
    keyStatus = 1
    while i < len(df):
        addr = df['Address'][i]
        url = 'https://maps.googleapis.com/maps/api/geocode/xml?address=' + addr + '&key=' + key_list[int(key_num1)]
        r = requests.get(url)
        content = r.content
        bsobj = BeautifulSoup(content, 'html.parser')
        status = bsobj.find('status').get_text()
        if status == 'OVER_QUERY_LIMIT':
            print('need to change key, the current file number is ' + str(i))
            key_num1 = int(key_num1) + 1
            print('key number has changed to ' + str(key_num1))
            i-=1
            if key_num1 > len(key_list) - 1:
                keyStatus = 0
                break
        elif status == 'OK':
            lat = bsobj.find_all('lat')[0].get_text()    
            long = bsobj.find_all('lng')[0].get_text()
            df['lat'][i] = lat
            df['long'][i] = long
        else:
            print('address is not vlaid')
            lat = 0
            long = 0
            df['lat'][i] = lat
            df['long'][i] = long
        if i % 500 == 0:
            print(i)
            print('緯度為: ' + str(lat))
            print('經度為: ' + str(long))
        i+=1
        time.sleep(1)        
    return df

# %%
for name in data:
    print(name)
    df = pd.read_excel(name)
    df = geoc(df, 0)
    if keyStatus == 0:
        break
    df.to_excel(name, index=False)
# Out:
# 士林區2017.xlsx
# the current key number is 0
# c:\python\python36-32\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\python\python36-32\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0
# 緯度為: 25.1048238
# 經度為: 121.5222604
# 500
# 緯度為: 25.1127502
# 經度為: 121.5332571
# 1000
# 緯度為: 25.0917608
# 經度為: 121.5069005
# 1500
# 緯度為: 25.0857725
# 經度為: 121.5194133
# 士林區2018.xlsx
# the current key number is 0
# c:\python\python36-32\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 0
# 緯度為: 25.1016704
# 經度為: 121.5285808
# need to change key, the current file number is 42
# key number has changed to 1
# 500
# 緯度為: 25.0872039
# 經度為: 121.5178478

# %%
def timeTransform(time):
    time_cut = time.replace('年', '-').replace('月', '')
    return time_cut
df.dealTime = df.dealTime.apply(timeTransform)
for name in data:
    df = pd.read_excel(name)
    print("目前轉換檔案: " + name)
    df.dealTime = df.dealTime.apply(timeTransform)
    df.to_excel(name, index=False)

# %%
for name in data:
    df = pd.read_excel(name)
    print("目前轉換檔案: " + name)
    print(len(df))
    df = df[df['Address'].isnull() != True]
    print(len(df))
    forname = name[6:13]
    fullname = forname + '.xlsx'
    print(fullname)
    df.to_excel(fullname, index=False)
# Out:
# 目前轉換檔案: .\中山區\中山區2008.xlsx
# 1708
# 1706
# 中山區2008.xlsx
# 目前轉換檔案: .\中山區\中山區2009.xlsx
# 3625
# 3625
# 中山區2009.xlsx
# 目前轉換檔案: .\中山區\中山區2010.xlsx
# 3485
# 3485
# 中山區2010.xlsx
# 目前轉換檔案: .\中山區\中山區2011.xlsx
# 4177
# 4177
# 中山區2011.xlsx
# 目前轉換檔案: .\中山區\中山區2012.xlsx
# 4453
# 4453
# 中山區2012.xlsx
# 目前轉換檔案: .\中山區\中山區2013.xlsx
# 4581
# 4581
# 中山區2013.xlsx
# 目前轉換檔案: .\中山區\中山區2014.xlsx
# 4355
# 4355
# 中山區2014.xlsx
# 目前轉換檔案: .\中山區\中山區2015.xlsx
# 3985
# 3985
# 中山區2015.xlsx
# 目前轉換檔案: .\中山區\中山區2016.xlsx
# 3608
# 3608
# 中山區2016.xlsx
# 目前轉換檔案: .\中山區\中山區2017.xlsx
# 3704
# 3704
# 中山區2017.xlsx
# 目前轉換檔案: .\中山區\中山區2018.xlsx
# 1583
# 1583
# 中山區2018.xlsx
# 目前轉換檔案: .\中正區\中正區2008.xlsx
# 722
# 722
# 中正區2008.xlsx
# 目前轉換檔案: .\中正區\中正區2009.xlsx
# 1506
# 1506
# 中正區2009.xlsx
# 目前轉換檔案: .\中正區\中正區2010.xlsx
# 1345
# 1345
# 中正區2010.xlsx
# 目前轉換檔案: .\中正區\中正區2011.xlsx
# 1642
# 1642
# 中正區2011.xlsx
# 目前轉換檔案: .\中正區\中正區2012.xlsx
# 1547
# 1547
# 中正區2012.xlsx
# 目前轉換檔案: .\中正區\中正區2013.xlsx
# 1621
# 1621
# 中正區2013.xlsx
# 目前轉換檔案: .\中正區\中正區2014.xlsx
# 1653
# 1653
# 中正區2014.xlsx
# 目前轉換檔案: .\中正區\中正區2015.xlsx
# 1613
# 1613
# 中正區2015.xlsx
# 目前轉換檔案: .\中正區\中正區2016.xlsx
# 1583
# 1583
# 中正區2016.xlsx
# 目前轉換檔案: .\中正區\中正區2017.xlsx
# 1552
# 1552
# 中正區2017.xlsx
# 目前轉換檔案: .\中正區\中正區2018.xlsx
# 621
# 621
# 中正區2018.xlsx
# 目前轉換檔案: .\信義區\信義區2008.xlsx
# 1144
# 1144
# 信義區2008.xlsx
# 目前轉換檔案: .\信義區\信義區2009.xlsx
# 2532
# 2532
# 信義區2009.xlsx
# 目前轉換檔案: .\信義區\信義區2010.xlsx
# 2318
# 2318
# 信義區2010.xlsx
# 目前轉換檔案: .\信義區\信義區2011.xlsx
# 2973
# 2973
# 信義區2011.xlsx
# 目前轉換檔案: .\信義區\信義區2012.xlsx
# 2940
# 2940
# 信義區2012.xlsx
# 目前轉換檔案: .\信義區\信義區2013.xlsx
# 2981
# 2981
# 信義區2013.xlsx
# 目前轉換檔案: .\信義區\信義區2014.xlsx
# 2869
# 2869
# 信義區2014.xlsx
# 目前轉換檔案: .\信義區\信義區2015.xlsx
# 2687
# 2687
# 信義區2015.xlsx
# 目前轉換檔案: .\信義區\信義區2016.xlsx
# 2504
# 2504
# 信義區2016.xlsx
# 目前轉換檔案: .\信義區\信義區2017.xlsx
# 2463
# 2463
# 信義區2017.xlsx
# 目前轉換檔案: .\信義區\信義區2018.xlsx
# 999
# 999
# 信義區2018.xlsx
# 目前轉換檔案: .\內湖區\內湖區2008.xlsx
# 1243
# 1243
# 內湖區2008.xlsx
# 目前轉換檔案: .\內湖區\內湖區2009.xlsx
# 2545
# 2545
# 內湖區2009.xlsx
# 目前轉換檔案: .\內湖區\內湖區2010.xlsx
# 2583
# 2583
# 內湖區2010.xlsx
# 目前轉換檔案: .\內湖區\內湖區2011.xlsx
# 2979
# 2979
# 內湖區2011.xlsx
# 目前轉換檔案: .\內湖區\內湖區2012.xlsx
# 2913
# 2913
# 內湖區2012.xlsx
# 目前轉換檔案: .\內湖區\內湖區2013.xlsx
# 3234
# 3234
# 內湖區2013.xlsx
# 目前轉換檔案: .\內湖區\內湖區2014.xlsx
# 3036
# 3036
# 內湖區2014.xlsx
# 目前轉換檔案: .\內湖區\內湖區2015.xlsx
# 2697
# 2697
# 內湖區2015.xlsx
# 目前轉換檔案: .\內湖區\內湖區2016.xlsx
# 2496
# 2496
# 內湖區2016.xlsx
# 目前轉換檔案: .\內湖區\內湖區2017.xlsx
# 2555
# 2555
# 內湖區2017.xlsx
# 目前轉換檔案: .\內湖區\內湖區2018.xlsx
# 961
# 961
# 內湖區2018.xlsx
# 目前轉換檔案: .\北投區\北投區2008.xlsx
# 586
# 586
# 北投區2008.xlsx
# 目前轉換檔案: .\北投區\北投區2009.xlsx
# 1336
# 1336
# 北投區2009.xlsx
# 目前轉換檔案: .\北投區\北投區2010.xlsx
# 1169
# 1169
# 北投區2010.xlsx
# 目前轉換檔案: .\北投區\北投區2011.xlsx
# 1327
# 1327
# 北投區2011.xlsx
# 目前轉換檔案: .\北投區\北投區2012.xlsx
# 1542
# 1542
# 北投區2012.xlsx
# 目前轉換檔案: .\北投區\北投區2013.xlsx
# 1588
# 1588
# 北投區2013.xlsx
# 目前轉換檔案: .\北投區\北投區2014.xlsx
# 1543
# 1543
# 北投區2014.xlsx
# 目前轉換檔案: .\北投區\北投區2015.xlsx
# 1542
# 1542
# 北投區2015.xlsx
# 目前轉換檔案: .\北投區\北投區2016.xlsx
# 1430
# 1430
# 北投區2016.xlsx
# 目前轉換檔案: .\北投區\北投區2017.xlsx
# 1472
# 1472
# 北投區2017.xlsx
# 目前轉換檔案: .\北投區\北投區2018.xlsx
# 591
# 591
# 北投區2018.xlsx
# 目前轉換檔案: .\南港區\南港區2008.xlsx
# 444
# 444
# 南港區2008.xlsx
# 目前轉換檔案: .\南港區\南港區2009.xlsx
# 1049
# 1049
# 南港區2009.xlsx
# 目前轉換檔案: .\南港區\南港區2010.xlsx
# 893
# 893
# 南港區2010.xlsx
# 目前轉換檔案: .\南港區\南港區2011.xlsx
# 1177
# 1177
# 南港區2011.xlsx
# 目前轉換檔案: .\南港區\南港區2012.xlsx
# 1235
# 1235
# 南港區2012.xlsx
# 目前轉換檔案: .\南港區\南港區2013.xlsx
# 1230
# 1230
# 南港區2013.xlsx
# 目前轉換檔案: .\南港區\南港區2014.xlsx
# 1289
# 1289
# 南港區2014.xlsx
# 目前轉換檔案: .\南港區\南港區2015.xlsx
# 1145
# 1145
# 南港區2015.xlsx
# 目前轉換檔案: .\南港區\南港區2016.xlsx
# 1203
# 1203
# 南港區2016.xlsx
# 目前轉換檔案: .\南港區\南港區2017.xlsx
# 1113
# 1113
# 南港區2017.xlsx
# 目前轉換檔案: .\南港區\南港區2018.xlsx
# 489
# 489
# 南港區2018.xlsx
# 目前轉換檔案: .\士林區\士林區2008.xlsx
# 821
# 821
# 士林區2008.xlsx
# 目前轉換檔案: .\士林區\士林區2009.xlsx
# 1778
# 1778
# 士林區2009.xlsx
# 目前轉換檔案: .\士林區\士林區2010.xlsx
# 1609
# 1609
# 士林區2010.xlsx
# 目前轉換檔案: .\士林區\士林區2011.xlsx
# 1847
# 1847
# 士林區2011.xlsx
# 目前轉換檔案: .\士林區\士林區2012.xlsx
# 2061
# 2061
# 士林區2012.xlsx
# 目前轉換檔案: .\士林區\士林區2013.xlsx
# 2061
# 2061
# 士林區2013.xlsx
# 目前轉換檔案: .\士林區\士林區2014.xlsx
# 2058
# 2058
# 士林區2014.xlsx
# 目前轉換檔案: .\士林區\士林區2015.xlsx
# 2048
# 2048
# 士林區2015.xlsx
# 目前轉換檔案: .\士林區\士林區2016.xlsx
# 1976
# 1976
# 士林區2016.xlsx
# 目前轉換檔案: .\士林區\士林區2017.xlsx
# 1982
# 1982
# 士林區2017.xlsx
# 目前轉換檔案: .\士林區\士林區2018.xlsx
# 695
# 695
# 士林區2018.xlsx
# 目前轉換檔案: .\大同區\大同區2008.xlsx
# 468
# 468
# 大同區2008.xlsx
# 目前轉換檔案: .\大同區\大同區2009.xlsx
# 899
# 899
# 大同區2009.xlsx
# 目前轉換檔案: .\大同區\大同區2010.xlsx
# 889
# 889
# 大同區2010.xlsx
# 目前轉換檔案: .\大同區\大同區2011.xlsx
# 1084
# 1084
# 大同區2011.xlsx
# 目前轉換檔案: .\大同區\大同區2012.xlsx
# 1033
# 1033
# 大同區2012.xlsx
# 目前轉換檔案: .\大同區\大同區2013.xlsx
# 1140
# 1140
# 大同區2013.xlsx
# 目前轉換檔案: .\大同區\大同區2014.xlsx
# 1239
# 1239
# 大同區2014.xlsx
# 目前轉換檔案: .\大同區\大同區2015.xlsx
# 1131
# 1131
# 大同區2015.xlsx
# 目前轉換檔案: .\大同區\大同區2016.xlsx
# 1074
# 1074
# 大同區2016.xlsx
# 目前轉換檔案: .\大同區\大同區2017.xlsx
# 1063
# 1063
# 大同區2017.xlsx
# 目前轉換檔案: .\大同區\大同區2018.xlsx
# 449
# 449
# 大同區2018.xlsx
# 目前轉換檔案: .\大安區\大安區2008.xlsx
# 1426
# 1426
# 大安區2008.xlsx
# 目前轉換檔案: .\大安區\大安區2009.xlsx
# 3151
# 3151
# 大安區2009.xlsx
# 目前轉換檔案: .\大安區\大安區2010.xlsx
# 2961
# 2961
# 大安區2010.xlsx
# 目前轉換檔案: .\大安區\大安區2011.xlsx
# 3496
# 3496
# 大安區2011.xlsx
# 目前轉換檔案: .\大安區\大安區2012.xlsx
# 3395
# 3395
# 大安區2012.xlsx
# 目前轉換檔案: .\大安區\大安區2013.xlsx
# 3637
# 3637
# 大安區2013.xlsx
# 目前轉換檔案: .\大安區\大安區2014.xlsx
# 3406
# 3406
# 大安區2014.xlsx
# 目前轉換檔案: .\大安區\大安區2015.xlsx
# 3114
# 3114
# 大安區2015.xlsx
# 目前轉換檔案: .\大安區\大安區2016.xlsx
# 2986
# 2986
# 大安區2016.xlsx
# 目前轉換檔案: .\大安區\大安區2017.xlsx
# 2934
# 2934
# 大安區2017.xlsx
# 目前轉換檔案: .\大安區\大安區2018.xlsx
# 1211
# 1211
# 大安區2018.xlsx
# 目前轉換檔案: .\文山區\文山區2008.xlsx
# 746
# 746
# 文山區2008.xlsx
# 目前轉換檔案: .\文山區\文山區2009.xlsx
# 1726
# 1726
# 文山區2009.xlsx
# 目前轉換檔案: .\文山區\文山區2010.xlsx
# 1570
# 1570
# 文山區2010.xlsx
# 目前轉換檔案: .\文山區\文山區2011.xlsx
# 1969
# 1969
# 文山區2011.xlsx
# 目前轉換檔案: .\文山區\文山區2012.xlsx
# 2050
# 2050
# 文山區2012.xlsx
# 目前轉換檔案: .\文山區\文山區2013.xlsx
# 2096
# 2096
# 文山區2013.xlsx
# 目前轉換檔案: .\文山區\文山區2014.xlsx
# 2026
# 2026
# 文山區2014.xlsx
# 目前轉換檔案: .\文山區\文山區2015.xlsx
# 2052
# 2052
# 文山區2015.xlsx
# 目前轉換檔案: .\文山區\文山區2016.xlsx
# 1955
# 1955
# 文山區2016.xlsx
# 目前轉換檔案: .\文山區\文山區2017.xlsx
# 1992
# 1992
# 文山區2017.xlsx
# 目前轉換檔案: .\文山區\文山區2018.xlsx
# 767
# 767
# 文山區2018.xlsx
# 目前轉換檔案: .\松山區\松山區2008.xlsx
# 921
# 921
# 松山區2008.xlsx
# 目前轉換檔案: .\松山區\松山區2009.xlsx
# 2097
# 2097
# 松山區2009.xlsx
# 目前轉換檔案: .\松山區\松山區2010.xlsx
# 1963
# 1963
# 松山區2010.xlsx
# 目前轉換檔案: .\松山區\松山區2011.xlsx
# 2233
# 2233
# 松山區2011.xlsx
# 目前轉換檔案: .\松山區\松山區2012.xlsx
# 2115
# 2115
# 松山區2012.xlsx
# 目前轉換檔案: .\松山區\松山區2013.xlsx
# 2235
# 2235
# 松山區2013.xlsx
# 目前轉換檔案: .\松山區\松山區2014.xlsx
# 2112
# 2112
# 松山區2014.xlsx
# 目前轉換檔案: .\松山區\松山區2015.xlsx
# 1984
# 1984
# 松山區2015.xlsx
# 目前轉換檔案: .\松山區\松山區2016.xlsx
# 1768
# 1768
# 松山區2016.xlsx
# 目前轉換檔案: .\松山區\松山區2017.xlsx
# 1872
# 1872
# 松山區2017.xlsx
# 目前轉換檔案: .\松山區\松山區2018.xlsx
# 752
# 752
# 松山區2018.xlsx
# 目前轉換檔案: .\萬華區\萬華區2008.xlsx
# 488
# 488
# 萬華區2008.xlsx
# 目前轉換檔案: .\萬華區\萬華區2009.xlsx
# 1140
# 1140
# 萬華區2009.xlsx
# 目前轉換檔案: .\萬華區\萬華區2010.xlsx
# 1178
# 1178
# 萬華區2010.xlsx
# 目前轉換檔案: .\萬華區\萬華區2011.xlsx
# 1277
# 1277
# 萬華區2011.xlsx
# 目前轉換檔案: .\萬華區\萬華區2012.xlsx
# 1390
# 1390
# 萬華區2012.xlsx
# 目前轉換檔案: .\萬華區\萬華區2013.xlsx
# 1410
# 1410
# 萬華區2013.xlsx
# 目前轉換檔案: .\萬華區\萬華區2014.xlsx
# 1463
# 1463
# 萬華區2014.xlsx
# 目前轉換檔案: .\萬華區\萬華區2015.xlsx
# 1367
# 1367
# 萬華區2015.xlsx
# 目前轉換檔案: .\萬華區\萬華區2016.xlsx
# 1412
# 1412
# 萬華區2016.xlsx
# 目前轉換檔案: .\萬華區\萬華區2017.xlsx
# 1357
# 1357
# 萬華區2017.xlsx
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-76-33284cc0ba3c> in <module>()
#       1 for name in data:
# ----> 2     df = pd.read_excel(name)
#       3     print("目前轉換檔案: " + name)
#       4     print(len(df))
#       5     df = df[df['Address'].isnull() != True]
#
# c:\python\python36-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# c:\python\python36-32\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
#     232     return io._parse_excel(
#
# c:\python\python36-32\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     292             self.book = xlrd.open_workbook(file_contents=data)
#     293         elif isinstance(self._io, compat.string_types):
# --> 294             self.book = xlrd.open_workbook(self._io)
#     295         else:
#     296             raise ValueError('Must explicitly set engine if not passing in'
#
# c:\python\python36-32\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     160         formatting_info=formatting_info,
#     161         on_demand=on_demand,
# --> 162         ragged_rows=ragged_rows,
#     163         )
#     164     return bk
#
# c:\python\python36-32\lib\site-packages\xlrd\book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      89         t1 = time.clock()
#      90         bk.load_time_stage_1 = t1 - t0
# ---> 91         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      92         if not biff_version:
#      93             raise XLRDError("Can't determine file's BIFF version")
#
# c:\python\python36-32\lib\site-packages\xlrd\book.py in getbof(self, rqd_stream)
#    1269             bof_error('Expected BOF record; met end of file')
#    1270         if opcode not in bofcodes:
# -> 1271             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1272         length = self.get2bytes()
#    1273         if length == MY_EOF:
#
# c:\python\python36-32\lib\site-packages\xlrd\book.py in bof_error(msg)
#    1263         if DEBUG: print("reqd: 0x%04x" % rqd_stream, file=self.logfile)
#    1264         def bof_error(msg):
# -> 1265             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1266         savpos = self._position
#    1267         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'dealTime'

# %%
df.head()
# Out:
#   dealTime Usage  Type    Address  Area rentPrice Pattern  Floor  floorSum  \
# 0  2012-12  整層住家  電梯大樓     北投區新民路    15    15,000  2房2廳1衛      1         9
# 1  2012-12  整層住家  電梯大樓     北投區稻香路    18    18,000  2房1廳2衛      5        11
# 2  2012-12  整層住家   透天厝   北投區東華街二段    45    32,000  3房2廳2衛      3         3
# 3  2012-12  整層住家  電梯大樓     北投區懷德街    17    19,000  2房2廳1衛      4         7
# 4  2012-12  整層住家    公寓  北投區致遠一路一段    25    14,000  2房2廳1衛      1         4
#
#          lat        long
# 0  25.139959  121.509993
# 1  25.143099  121.486022
# 2  25.120441  121.509407
# 3  25.112866  121.519576
# 4  25.108737  121.516037

# %%
def geoc_temp(df, key_num1):
    if 'lat' not in df.columns:
        df['lat'] = pd.Series(np.zeros(len(df)), index=df.index)
        df['long'] = pd.Series(np.zeros(len(df)), index=df.index)
#     start_n = input("starting number ")
    print("the current key number is " + str(key_num1))
#     for i in range(int(start_n), len(df)):
    num = input("enter the current file number ")
    i = int(num)
    global keyStatus
    keyStatus = 1
    while i < len(df):
        addr = df['Address'][i]
        url = 'https://maps.googleapis.com/maps/api/geocode/xml?address=' + addr + '&key=' + key_list[int(key_num1)]
        r = requests.get(url)
        content = r.content
        bsobj = BeautifulSoup(content, 'html.parser')
        status = bsobj.find('status').get_text()
        if status == 'OVER_QUERY_LIMIT':
            print('need to change key, the current file number is ' + str(i))
            key_num1 = int(key_num1) + 1
            print('key number has changed to ' + str(key_num1))
            i-=1
            if key_num1 > len(key_list) - 1:
                keyStatus = 0
                break
        elif status == 'OK':
            lat = bsobj.find_all('lat')[0].get_text()    
            long = bsobj.find_all('lng')[0].get_text()
            df['lat'][i] = lat
            df['long'][i] = long
        else:
            print('address is not vlaid')
            lat = 0
            long = 0
            df['lat'][i] = lat
            df['long'][i] = long
        if i % 500 == 0:
            print(i)
            print('緯度為: ' + str(lat))
            print('經度為: ' + str(long))
        i+=1
        time.sleep(1)        
    return df

# %%
df = geoc_temp(df, 0)
# Out:
# the current key number is 0
# enter the current file number 1500
# c:\python\python36-32\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\python\python36-32\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1500
# 緯度為: 25.0908703
# 經度為: 121.5245693

# %%
name
# Out:
# '士林區2018.xlsx'

# %%
df.to_excel(data[0], index=False)

# %%
df.head()
# Out:
#   dealTime Usage Type   Address  Area rentPrice Pattern  Floor  floorSum  \
# 0  2016-12  整層住家   公寓  士林區忠誠路二段    44    30,000  4房2廳2衛      4         5
# 1  2016-12  整層住家   公寓  士林區承德路四段    23    23,000  2房1廳1衛      2         5
# 2  2016-12  整層住家   公寓  士林區芝玉路一段    34    25,000  3房2廳2衛      2         5
# 3  2016-12  整層住家   公寓    士林區通河街    10     9,000  1房2廳1衛      2         5
# 4  2016-12  整層住家   公寓    士林區東山路    28    23,000  3房2廳2衛      4         5
#
#          lat        long
# 0  25.114040  121.532336
# 1  25.085233  121.523301
# 2  25.105259  121.535303
# 3  25.080426  121.521728
# 4  25.114602  121.539172
